# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(0,10,1000)
y=x
plt.plot(x,y)

# %%
x=np.linspace(0,10,100)
y=x
plt.scatter(x,y)

# %%
x=np.linspace(0,10,11)
y=x
plt.scatter(x,y)

# %%
x=np.linspace(0,10,1000)
y=x
noise=np.random.randn(1000)*5
y1=y+noise
plt.scatter(x,y1)
###what randn do is that it generates  a list random numbers whose mean is zero and standard deviation is 1

# %%
out=np.random.randn(1000)
out1=plt.hist(out,bins=200)
#bins as mentioned above about the slot or range, in our case it is 200 that is, 
# whatever 1000 values will be generated via random_integers will be divider by bin value and get plotted.
###what randn do is that it generates  a list random numbers whose mean is zero and standard deviation is 1
###see ar x=0 max elements are there and most of the values are between -1 and 1

# %%
out=plt.pie([100,200,300],explode=[0,.11,.20],radius=2)
##it just parts the section away as the no increses the distance increases

# %%
import seaborn as sns

# %%
out=np.random.randn(1000)
out1=sns.distplot(out,bins=200)
##this blue line is a kde distribution
# Out:
# c:\users\ritik\appdata\local\programs\python\python37\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
out=np.random.randn(1000)
out1=sns.distplot(out,bins=200,kde=False)

# %%
data=sns.load_dataset("iris")
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data=sns.load_dataset("iris")
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data=sns.load_dataset("iris")
sns.scatterplot(data["sepal_length"],data["sepal_width"])
# Out:
# c:\users\ritik\appdata\local\programs\python\python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
data=sns.load_dataset("iris")
sns.scatterplot(data["sepal_length"],data["sepal_width"],hue=data["petal_length"])
# Out:
# c:\users\ritik\appdata\local\programs\python\python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
data=sns.load_dataset("tips")
data
# sns.violinplot(x=data.)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
data=sns.load_dataset("tips")
sns.violinplot(x=data.total_bill)
##we used violinplot just to differentiate the outliers like her ethe blck dots are the outliers
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
data=sns.load_dataset("tips")
sns.violinplot(y=data.total_bill,hue=data.day)
# Out:
# <AxesSubplot:ylabel='total_bill'>

# %%
data=sns.load_dataset("tips")
sns.boxplot(x=data.total_bill)
##like here the blck dots are the outliers
# Out:
# <AxesSubplot:xlabel='total_bill'>
